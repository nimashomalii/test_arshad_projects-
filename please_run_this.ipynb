# %%
# !rm -rf arshad
# !git clone https://github.com/nimashomalii/arshad.git
# Out:
# Cloning into 'arshad'...
# remote: Enumerating objects: 402, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 402 (delta 26), reused 0 (delta 0), pack-reused 339 (from 2)
# Receiving objects: 100% (402/402), 128.75 KiB | 16.09 MiB/s, done.
# Resolving deltas: 100% (215/215), done.

# %%
# %cd arshad
# !pip install -r requirements.txt
# Out:
# /content/arshad
# ...

# %%
#!python mainProject.py 'simpleNN' 'dominance' 'binary' 10

# !python mainProject.py 'cnn_45138' 'valence' 'binary' 11
# Out:
# a new procedure is takeing place . . .
# DataExtractor مقداردهی اولیه شد. مسیر استخراج پیش فرض: extracted_rar
# در حال دانلود فایل از Google Drive (ID: 1UHFqTECwXi16FNzts_gpmAqGpx5GpOsu)...
# Downloading...
# From (original): https://drive.google.com/uc?id=1UHFqTECwXi16FNzts_gpmAqGpx5GpOsu
# From (redirected): https://drive.google.com/uc?id=1UHFqTECwXi16FNzts_gpmAqGpx5GpOsu&confirm=t&uuid=ebbe5310-2344-46c3-8255-4055c0919582
# To: /content/arshad/extracted_rar/data.rar
# 100% 339M/339M [00:08<00:00, 40.6MB/s]
# فایل 'data.rar' با موفقیت دانلود شد.
# در حال استخراج فایل RAR به: extracted_rar...
# فایل 'data.rar' با موفقیت استخراج شد.
#
# --- محتویات پوشه استخراج شده ---
# 📂 extracted_rar/
#     📄 data.rar
#     📂 EEG_data/
#         📄 stimuli_7_clip.pkl
#         📄 stimuli_6_clip.pkl
#         📄 stimuli_5_clip.pkl
#         📄 stimuli_17_clip.pkl
#         📄 stimuli_13_clip.pkl
#         📄 stimuli_16_clip.pkl
#         📄 stimuli_0_clip.pkl
#         📄 stimuli_10_clip.pkl
# ...

# %%
from IPython.display import Image
display(Image("loss_plot.png"))
display(Image("accuracy_plot.png"))
